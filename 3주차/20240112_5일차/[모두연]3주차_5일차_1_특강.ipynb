# %%
# 블로그 작성 : 단지 정보성이면 차별성이 부족함. 실제 문제해결능력이 보이는 게 중요
# 어떤 문제를 만나서 어떻게 해결했는 지 식의 내용이 중요함.

# 오픈소스를 기여할 지 아닐지 포커스를 정함
# 오픈소스 기여 원하면 활동 내역을 만들기(github, star, contribute)

# 어떤 산업군/회사로 가고 싶은지. 회사가 있다면 요구사항이 뭔지 분석 -> 거기에 맞게 준비

# 커뮤니티나 동아리 등 협업 경험이 중요(협업 능력)

# 순전히 자신의 노력으로 해봤는 지를 보여줄 자료 필요


# 기존 프로젝트 개선
# -> 1.새로운 기능 추가 (내 기획역량 보여줌)
# -> 2. 코드 개선(기존 사용했던 기술 보완점 제시, 코드 리팩토링을 통해 성장을 보여줌)
# 이러한 것들도 명확한 근거가 중요
# 수료 이후에도 시간과 노력을 들이는 게 가장 중요함(자기 의지대로 뭔가 하는 사람인지를 보여줄 수 있음)

# 부트캠프 수료 이후 계획이 중요(어떻게 일을 할 것인가)

# 포트폴리오?
# 자기만의 웹페이지로 포트폴리오 보여줄 수 있음.
# 본인이 어떤 문법을 써서 개발했는지 간단히 보여줄 수 있어야하고
# 포트폴리오를 개괄적으로 표현할 수 있어야 한다.
# 링크와 시연 영상을 만들어도 좋음.
# 기능에 대한 기획 + 명료하게 정리한 노력이 보여야함.
# 라이브러리를 이용했으면 왜 이용했는지 어떻게 사용했는 지
# 에러상황에서는 어떻게 처리했는지
# 기술스택은 별로 임팩트는 보여주지 않음. - 이런 거 써봤구나 이해정도 보여줌 -> 면접에서는 이런 거 물어보겠다 생각함.
# 본인의 제품 설계도면(architecture, data flow)가 필요
# 지원하고자하는 회사에 대한 정리 - 이 회사는 이럴거 같다. 여기 와서는 내가 어떻게 기여할 수 있는지?
# 내가 해결할 수 있는 부분은 어떤 게 있는지
# 사용자 관점에서 생각할 수 있는지 역량 필요

# postman 문서 링크 예
# 지원하고자하는 회사의 기능분석, 예상 시스템 구성도, api수집해서, 어떤 api사용해서 호출하는지 테스트 및 정리 -> 문서화,
# 아키텍쳐를 리버스 엔지니어링 하듯이 포트폴리오 만듬


# 소비자의 관점
# 페이지 별 설명
# 개발 개요

# 스타트 업 지원시, 얼마나 전략적인지 역량을 잘 보여줘야함.

# 파이썬 백엔드만으로는 찾을 수 있는 폭이 좁음.
# 지원하고자 한다는 영역이 있으면, 그걸 요구하는 회사의 폭이 얼마나 되는 지 확인이 필요

# 연구원
# 석박에 요구되는 논문을 빠르게 읽고, 구현할 수 있는지

# 내가 짠 코드가 실제로 사회에서 도움이 되는가 생각해볼 필요있음.

# 회사만 보지말고 회사의 현직자의 얘기를 들어봐야함.
# 회사에는 많은 조직이 있고, 그 조직에서 일하는 게 다다름
# 가고자하는 부서의 정보도 습득 필요.

# 이력서 자신없어도 미리 미리 준비
