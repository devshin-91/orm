# %% [markdown]
# # While

# %%
# 쉘 프로그래밍 예

import os


while True:
    userinput = input('>')
    if userinput == 'pwd':
        # print('현재 위치 출력')
        # print('\\'.join(__file).split('\\')[:-1])
        print(os.getcwd())
    elif userinput == 'dif' or userinput == 'ls':
        print(os.listdir(os.getcwd()))
    elif userinput == 'exit':
        print('안녕히가세요.')
        break

# %% [markdown]
# # break 과 continue
# - break : 반복문을 즉시 종료
# - continue : 반복문의 나머지 부분을 건너뛰고, 반복문을 다음 반복으로 즉시 이동

# %%
for i in range(10):
    i += 1
    if i == 5: # i가 5일때 멈춰라
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(10):
    if i % 2 == 0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10):
    if i % 2 == 0:
        print(i) # 조건문을 거친 i 가 출력됨
    print(i) # 조건문을 거치지 않은 i가 출력됨
# Out:
# 0
# 0
# 1
# 2
# 2
# 3
# 4
# 4
# 5
# 6
# 6
# 7
# 8
# 8
# 9

# %%
# continue의 기능
# 조건을 만족시키는 경우 건너뛰어서 조건 바로 위로 올라감.

#
for i in range(10): # 0~9
    if i % 2 == 0: # 짝수인 경우에 하단 코드블럭을 실행!
        continue   # 짝수인 경우에 실행한 구문이 continue -> 짝수일때 -> 다시 반복문 다음순서로 이동!
    print(i)       # for문안에 if문 실행된 후에 차례대로 print(i)
# i : 1, 2(continue로 for문으로 돌아감), 3, 4(continue), ......


#
for i in range(10): # 0~9
    if i % 2 == 0:  # 짝수인 경우에 하단 코드블럭을 실행!
        print(i)    # 짝수인 경우에만 출력

#
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
import random

answer = random.randint(1, 1000)

while True:
    userinput = int(input('숫자를 입력해주세요.'))
    if userinput > answer:
        print('Down')

    elif userinput < answer:
        print('Up')

    else:
        print('축하합니다! 맞추셨어요!')
        break
# Out:
# 숫자를 입력해주세요.1
# Up
# 숫자를 입력해주세요.2
# Up
# 숫자를 입력해주세요.3
# Up
# 숫자를 입력해주세요.4
# Up
# 숫자를 입력해주세요.5
# Up
# 숫자를 입력해주세요.6
# Up
# 숫자를 입력해주세요.100
# Up
# 숫자를 입력해주세요.1000
# Down
# 숫자를 입력해주세요.400
# Up
# 숫자를 입력해주세요.500
# Up
# 숫자를 입력해주세요.600
# Up
# 숫자를 입력해주세요.700
# Up
# 숫자를 입력해주세요.800
# Up
# 숫자를 입력해주세요.900
# Down
# 숫자를 입력해주세요.870
# Down
# 숫자를 입력해주세요.860
# Down
# 숫자를 입력해주세요.830
# Up
# 숫자를 입력해주세요.850
# Up
# 숫자를 입력해주세요.858
# Down
# 숫자를 입력해주세요.855
# Down
# 숫자를 입력해주세요.854
# Down
# 숫자를 입력해주세요.853
# Down
# 숫자를 입력해주세요.852
# 축하합니다! 맞추셨어요!

# %%
# 중첨 while문
while i <10: # i 10 이하 -> 실행
    while j < 10: # j 10 이하 -> 실행
        print(f'{i} X {j} ={i * j}') # error : i, j가 선언되지 않음
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7d6dc4278095> in <cell line: 2>()
#       1 # 중첨 while문
#       2 while i <10: # i 10 이하 -> 실행
# ----> 3     while j < 10: # j 10 이하 -> 실행
#       4         print(f'{i} X {j} ={i * j}')
#
# NameError: name 'j' is not defined

# %%
i = 2
while i < 10 : # i 가 10보다 같거나 클떄까지 실행
    j = 1
    while j < 10: # j가 10보다 같거나 클때까지 실행
        print(f'{i} X {j} = {i * j}') # 상위 while에서의 i와 현재 while문의 j를 활용해서 print
        j += 1
    i += 1 # 하위 while문 끝나면 상위 while문의 문장으로써 수행됨
# Out:
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81

# %%
# rror
i = 2
while i < 10 :
    while j < 10:
        print(f'{i} X {j} = {i * j}')
        j += 1
    i += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-005e30421c22> in <cell line: 3>()
#       2 i = 2
#       3 while i < 10 :
# ----> 4     while j < 10:
#       5         print(f'{i} X {j} = {i * j}')
#       6         j += 1
#
# NameError: name 'j' is not defined

# %%
# 중첩 for문이나 중첩 while문은 방향성이 똑같다.

# %% [markdown]
# # break, continue, pass

# %%
# switch 활용

# switch 변수 둠 => 중접 반복문 탈출
# 하지만 이 방법의 경우, 반복문 중첩이 될수록 코드 복잡도가 올라감.

switch = 0 # 반복문 탈출용 스위치
for i in range(5):
    if switch == 1: # 반복문 탈출 조건
        break
    for j in range(5):
        if j == 3:
            switch = 1
            break
        print(f'{i}, {j}')

# %%
# 예외 처리
# try 안에 예외 조건 -> 해당 조건에서 예외 발생 -> except구문으로 예외에 대해 처리 -> 전체 구문 탈출

# https://peps.python.org/pep-3136/

try:
    for i in range(2, 10):
        for j in range(1, 10):
            if j == 3: # j == 3일경우
                raise StopIteration # 예외 : StopIteration을 raise
            print(f'{i} X {j} = {i*j}')
except StopIteration: # Try에서 raise한 예외에 대해서 아래 같이 예외처리하겠다.
    print("Done") # 에러 대신 이걸 출력하고 끝냄

# %% [markdown]
# # 반복문 else

# %% [markdown]
# ## for, else

# %% [markdown]
# * 기본 형태
# ```python
# for 변수 in 범위:
#     pass # 반복 실행할 코드
# else:
#     pass # 반복문이 모두 실행되어 종료되고 실행할 코드
# ```

# %%
for i in range(100):
    print(f'{i} 물고기를 잡았습니다.')
    if i == 5:
        print('만선입니다. 물고기를 다 잡았습니다.')
        break
else: # for문이 break가 없이 정상 종료되었을때 실행됨.
    print('아직 여유가 좀 있지만, 물고기가 더 없는 것 같으니 이정도로 만족하고 돌아갑시다.')
print('수고하셨습니다.')

# %%
for i in range(4):
    print(f'{i} 물고기를 잡았습니다.')

else: # for문이 break가 없이 정상 종료되었을때 실행됨.
    print('아직 여유가 좀 있지만, 물고기가 더 없는 것 같으니 이정도로 만족하고 돌아갑시다.')
print('수고하셨습니다.')
# Out:
# 0 물고기를 잡았습니다.
# 1 물고기를 잡았습니다.
# 2 물고기를 잡았습니다.
# 3 물고기를 잡았습니다.
# 아직 여유가 좀 있지만, 물고기가 더 없는 것 같으니 이정도로 만족하고 돌아갑시다.
# 수고하셨습니다.

# %% [markdown]
# ## while, else

# %% [markdown]
# * 기본 형태
# ```python
# while 조건:
#     pass # 반복 실행할 코드
# else:
#     pass # while 반복문이 모두 실행되어 종료되고 실행할 코드
# ```

# %%
# while문 정상 종료되는 경우
n = 0
while n < 5:
    print(f'현재 숫자는 {n}입니다.')
    n += 1
else:
    print('반복문을 종료합니다.')
# Out:
# 현재 숫자는 0입니다.
# 현재 숫자는 1입니다.
# 현재 숫자는 2입니다.
# 현재 숫자는 3입니다.
# 현재 숫자는 4입니다.
# 반복문을 종료합니다.

# %%
# break -> while문 정상종료x => else: 수행 x
n = 0
while n < 5:
    print(f'현재 숫자는 {n}입니다.')
    n += 1
    if n > 3:
        break
else: # break x, 정상종료 => else가 실행됨
    print('반복문을 종료합니다.')
