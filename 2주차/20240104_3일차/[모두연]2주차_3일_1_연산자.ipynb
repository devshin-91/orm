# %%
# 2. 비교연산

# %%
# 3. 논리연산

# %%
# 4. 할당연산

# %%
# 5. 식별연산

# %%
# 6. 멤버연산

# %%
# 기본 예시
a = [1, 2, 3, 4]
b = [1, 2, 3, 4]
c = "hello world"

print(1 in a)
# Out:
# True

# %%
print(0  not in a)
# Out:
# True

# %%
print([2] in b) # [2]는 리스트형 a의 2는 정수형
# Out:
# False

# %%
# 자료형태를 잘 파악해서 In을 사용해야 한다.
a_1 = [[1, 2], 3, 4]
# 리스트 안에 있는 값은 정수형  3, 4 / 리스트형 [1, 2]

# %%
print([2] in a_1)
# Out:
# True

# %%
print([1, 2] in a_1)
# Out:
# True

# %%
print()

# %%
print([2] in b)
print([1, 2] in b)

# %%
result = 2 ** 3 * 3 + 4 / 2 - 5
print(result)
# Out:
# 21.0

# %% [markdown]
# # 실습 2

# %% [markdown]
# 1. 사용자 입력받기:
#   - `input()` 함수를 사용하여 제품의 원가와 할인율을 입력받습니다.
#
# 2. 문자열을 숫자로 변환:
#   - 입력받은 원가와 할인율을 각각 `float()` 함수를 사용하여 실수로 변환합니다.
#
# 3. 할인된 가격 계산:
#   - 할인된 가격을 계산하는 공식을 사용합니다. (할인된 가격 = 원가-(원가*할인율 /100))
#
# 4. 결과 출력:
#   - 계산된 할인된 가격을 `print()`함수를 사용하여 출력합니다.

# %%
# Step1: 제품의 원가와 할인율 입력 받기
original_price = float(input("제품의 금액을 입력해주세요: "))
discount_rate = float(input("제품의 할인율을 입력해주세요: "))
# Out:
# 제품의 금액을 입력해주세요: 2000
# 제품의 할인율을 입력해주세요: 80

# %%
# Step2: 할인된 가격 계산
discounted_price = original_price - (original_price * discount_rate / 100)

# %%
# Step3: 결과 출력
print(f"할인된 가격은 {int(discounted_price)}원입니다.")
# Out:
# 할인된 가격은 400원입니다.

# %% [markdown]
# 단계별 가이드
# - 사용자 입력 받기:
#   - input() 함수를 사용하여 사용자의 이름과 나이를 입력받습니다.
# - 문자열을 숫자로 변환:
#   -입력받은 나이(문자열)를 int() 함수를 사용하여 정수로 변환합니다.
# - 산술 연산 수행:
#   - 변환된 나이에 1을 더하여 다음 해의 나이를 계산합니다.
# - 문자열 길이 계산:
#  - len() 함수를 사용하여 사용자 이름의 길이를 계산합니다.
# - 성인 여부 판단:
#   - 나이를 기준으로 성인 여부를 판단하여 불리언 값으로 표시합니다. (예: 18세 이상이면 True, 그렇지 않으면 False)
# - 결과 출력:
#   - 계산된 나이, 이름의 길이, 성인 여부를 print() 함수를 사용하여 출력합니다.

# %%
# Step 1
u_name = input("사용자의 이름을 입력해주세요: ")
u_age = input("사용자의 나이를 입력해주세요: ")

# Step 2
u_age = int(u_age)

# Step 3
nxt_age = u_age + 1
print(f"다음 해의 나이는 {nxt_age}살 입니다.")

# Step 4
length_name = len(u_name) # 이름의 길이
# print(length_name)

# Step 5
is_adult = u_age >= 18
# print(is_adult)

# Step 6
print(f"사용자의 나이는 {u_age}이고 이름 길이는 {length_name}입니다. 사용자의 성인 여부는 {is_adult}입니다")
# Out:
# 사용자의 이름을 입력해주세요: lion
# 사용자의 나이를 입력해주세요: 33
# 다음 해의 나이는 34살 입니다.
# 사용자의 나이는 33이고 이름 길이는 4입니다. 사용자의 성인 여부는 True입니다

# %% [markdown]
# 블로그용 정리
#
# ```python
# # Step 1 : 사용자 입력 받기
# u_name = input("사용자의 이름을 입력해주세요: ")
# u_age = input("사용자의 나이를 입력해주세요: ")
#
# # Step 2 : 문자열을 숫자로 변환
# u_age = int(u_age)
#
# # Step 3 : 산술 연산 수행
# nxt_age = u_age + 1
# print(f"다음 해의 나이는 {nxt_age}살 입니다.")
#
# # Step 4 : 문자열 길이 계산
# length_name = len(u_name) # 이름의 길이
# # print(length_name)
#
# # Step 5 : 성인 여부 판단
# is_adult = u_age >= 18
# # print(is_adult)
#
# # Step 6 : 결과 출력
# print(f"사용자의 나이는 {u_age}이고 이름 길이는 {length_name}입니다. 사용자의 성인 여부는 {is_adult}입니다")
#  ```
