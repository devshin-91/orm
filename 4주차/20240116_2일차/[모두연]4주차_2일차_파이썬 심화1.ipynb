# %% [markdown]
# # 메서드 체이닝

# %%
# 매우 중요!
# 복습 꼭 해야

'Hello World'.replace('Hello', 'hi').lower()
# 그 메서드에 리턴된 값이 순차적으로 해소가 되는 방식

# 'hello world'.a().b().c().d() # 해소가 된 메서드의 결과값이 따라오는 메서드에 사용되는 체인 방식

# 'hellow World'.split().lower() # error ; lower() 앞의 반환값이 lower() 메서드를 쓸 수 없음 ~~~
'Hello World'.split()[0].lower()
# Out:
# 'hello'

# %%
class Calculator:
    def __init__(self, value):
        self.value = value

    def add(self, other):
        self.value += other
        return self

    def subtract(self, other):
        self.value -= other
        return self

    def multiply(self, other):
        self.value *= other
        return self

    def get_value(self):
        return self.value

calc = Calculator(1)
result = calc.add(2).subtract(1).multiply(3).get_value() # 메서드 체이닝 끝에 .get_value의 결과가 int 자료형이어서 그 뒤로 해당 클래스의 메서드가 이어질 수 없음.
print(result)  # 결과: 6

# 메서드 여러개 사용하는 건 권장하지 않고 분기를 두는 게 더 좋음.

# %%
# int
# float
# complex
a = 3
b = 3.5
c = 3j + 1

dir(a)
dir(b)
dir(c)

# 'imag' # 허수부
# 'real' # 실수부
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  'conjugate',
#  'imag',
#  'real']

# %% [markdown]
# # 일급함수와 고차함수

# %%
# 일급 함수는 함수를 값으로 취급하는 것을 얘기합니다.

def greet(name):
    return f'Hello, {name}'

say_hello = greet
print(say_hello("World"))
# Out:
# Hello, World

# %%
p = print
p('hello')
# Out:
# hello

# %%
l = [10, 20, 30]
# l.append(100)
add = l.append # 실제 프로젝트에서는 이렇게 사용 x
add(10)
add(20) # 굳이 이렇게 사용하는 경우는, 변수가 너무 길거나 오타가 많이나거나 메서드명이 너무길때
l
# Out:
# [10, 20, 30, 10, 20]

# %%
# 위와 같은 화살표입니다.
a = 10
b = a
c = b

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

funcs = [add, subtract]
print(funcs[0](2, 3)) # 출력: 5 ; funcs[0] => add
# Out:
# 5

# %%
class Operator:
    def add(self, x, y):
        return x + y

    def sub(self, x, y):
        return x - y

    def mul(self, x, y):
        return x * y

    def div(self, x, y):
        return x / y

    def _and(self, x, y):
        pass

    def _or(self, x, y):
        pass

op = Operator()
logical_op = {
    'add': op.add,
    'sub': op.sub,
    'mul': op.mul,
    'div': op.div,
}
arithmetic_op = {
    '_and': op._and,
    '_or': op._or,
}

print(logical_op['add'](2, 3)) # 출력: 5 ; logical_op['add']와 op.add 가 가리키는 공간이 같다!
print(op.add(2, 3)) # 출력: 5

for _, f in logical_op.items():
    print(f(2, 3)) # 4칙연산 모두 계산

# %%
def add(a, b):
    return a + b

add(2, 3)
# Out:
# 5

# %%
# 우리가 실제 코딩하는 것은 여러 클래스 또는 인스턴스의 조합으로 이뤄져 있습니다.
# Django만 하더라도 대부분의 것들이 class로 구현되어 있습니다.
# 인스턴스나 클래스에 직접접근하지 않고 내가 만든 변수로 관리할 수 있습니다.

# %%
# 별표 1개 => 데코레이터를 이해하기 위해 중요한 개념입니ㅏㄷ.

def add(a, b):
    return a + b

def say_hello(name):
    return f'Hello, {name}'

def greet(func, name):
    return func(name)

print(greet(say_hello, 'World')) # 출력: Hello, World
# Out:
# Hello, World

# %%
def add(a, b):
    return a + b

def say_hello(name):
    return f'Hello, {name}'

def greet(func, name):
    return func(name)

print(greet(say_hello, 'World')) # 출력: Hello, World
# Out:
# Hello, World

# %%
# 함수를 리턴할 수 있다! (데코레이터의 핵심 개념)
def create_adder(x):
    def adder(y):
        return x + y
    return adder

add_5 = create_adder(5)
print(add_5(10))  # 출력: 15

# %%
# 밖에서 함수 안에 있는 값을 참조하지 못합니다.
def f():
    x = 10
    y = 20
    return x + y

f()
x # error ;  함수가 끝나서 더 이상 활용되지않는 변수는 사라진다.

# %%
one = 100
def f():
    x = one + 10
    y = 20
    return x + y

f()
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-21f9613682f5> in <cell line: 8>()
#       6
#       7 f()
# ----> 8 x
#
# NameError: name 'x' is not defined

# %%
# 복습 x
x = 100
def one():
    def two():
        def three():
            print(x)
            return
        three()
    two()

one()

# 나를 감싸고 있는 거에서 먼저 찾고, 없으면 그 위에 있는 걸 찾는다.
# Out:
# 100

# %%
# 함수를 리턴할 수 있다! (데코레이터의 핵심 개념)
# 중요한 개념: x라는 변수가 함수가 끝났는데도 불구하고 살아있다? 클로져!
def create_adder(x):
    def adder(y):
        return x + y
    return adder # 핵심!

add_5 = create_adder(5)
print(add_5(10))  # 출력: 15

# %%
def create_sq(x):
    def sq(y):
        return x ** y
    return sq

제곱2 = create_sq(2) # create_sq(2) => 함수 안의 x가 2고, 하위 함수에서의 x또한 2로 쓰인다. 즉, x가 2로 불변상태. x를 감추기 위한 코딩 기법
제곱3 = create_sq(3)
제곱4 = create_sq(4)

제곱2(2), 제곱2(3), 제곱2(4) # => 전부 x가 2로 고정
제곱3(2), 제곱3(3), 제곱3(4) # => 전부 x가 3로 고정
제곱4(2), 제곱4(3), 제곱4(4)

# %% [markdown]
# # 여러 개의 값 반환

# %%
def add_and_subtract(x, y):
    addition = x + y
    subtraction = x - y
    return addition, subtraction

# 함수 호출
result = add_and_subtract(5, 3)

# 결과 출력
print(result)  # 출력: (8, 2)

# %% [markdown]
# # 재귀함수

# %%
# 내가 나를 호출하는 함수
# 재귀는 내가 정말 재귀에 자신있다가 아니면 반복문을 사용하자.
# 재귀를 억지로 사용하려하지 말자.
# 재귀를 잘못 사용하면 비효율의 끝판왕이 됨.

# %%
# 이런 코드를 연습해봄으로 재귀에 친숙해질 수 있습니다.
# 분할 정복, 다이나믹 프로그래밍
# f(5) => 5 * 4 * 3 * 2 * 1 == 120 == 5! (수학 공식으로는 5!로 표현합니다.)

def f(n):
    if n <= 1: # 즉, n의 값이 1이하로 내려가기 전 까지는
        return n
    return n * f(n-1) # n * f(n-1)을 반환

f(5)

# 이해가 어렵다면 python tutor에서 그 과정을 보자
# https://pythontutor.com/render.html#mode=display
# Out:
# 120

# %%
# 권장합니다!
for i in range(1, 101):
    print(i)

# %%
def 숫자출력(count):
    if count > 100:
        return # return 뒤에 아무것도 없으면 None을 반환하는 거임. 굳이 return None이라고 안 쓰고 주로 return 만 씀.
    print(count)
    return 숫자출력(count+1) #값을 1부터 반복횟수 까지의 값을 출력

숫자출력(1)

# %%
# 권장합니다!
result = 1
for i in range(1, 6):
    result *= i
result
# Out:
# 120

# %%
# 설명
def f(n):
    if n <= 1:
        return n
    return n * f(n-1)

# 보는 순서     # 1step       # 2rd
f(5)    # -> 5 > 1 -> 5 * f(4) -> 5* 4* 3* 2* 1 => 120
f(4)    # -> 4 > 1 -> 4 * f(3) -> 앞에서 f(3)이 3 * f(2)야 -> 4* ( 3 * 2 * 1)
f(3)    # -> 3 > 1 -> 3 * f(2) -> 앞에서 f(2)가 2* f(1)이 었어 -> 3 * ( 2 * 1)
f(2)    # -> 2 > 1 -> 2 * f(1) -> 어 근데 앞에 f(1)은 1이네 -> 2 * ( 1 )
f(1)    # -> 1 <= 1 -> 1

# f(5) -> f(4) -> f(3) -> f(2) -> f(1) -> 2 f(1) -> 3 f(2) -> 4 f(3) -> 5 f(4)

# %%
s = ''
for i in 'hello':
    s = s + i

s

# s = 'h' + '' # 'hello'[0] + ''(최초 s)
# s = 'e + 'h #  앞은 한 글자만 나오고 이걸 뒤에거랑 더해져서 다음의 s에서 뒤로 나온다고 생각해보자! h, eh, leh, lleh, olleh
# s = 'l' + 'eh'
# Out:
# 'hello'

# %%
def f(s):
    if len(s) <= 1:
        return s
    return f(s[1:]) + s[0]

f('hello')

# step1                                # step2
거꾸로('hello') = 거꾸로('ello') + 'h' = 'olle' + 'h'
거꾸로('ello')  = 거꾸로('llo') + 'e'  = 'oll' + 'e'
거꾸로('llo')   = 거꾸로('lo') + 'l'   = 'ol' + 'l'
거꾸로('lo')    = 거꾸로('o') + 'l'    = 'o' + 'l'
거꾸로('o')     = 'o'                  = 'o'
