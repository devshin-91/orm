# %% [markdown]
# # 문제1: [게임 밸런스 조절](https://100.pyalgo.co.kr/?page=10)

# %%
'''
입출력 예
입력	출력
[['Licat', 98, 92, 85, 97], ['Mura', 95, 32, 51, 30], ['Binky', 98, 98, 51, 32]]	['Licat']
[['Gray', 98, 92, 85, 97], ['Gom', 98, 30, 21, 60], ['Allosa', 98, 90, 99, 98]]	['Allosa', 'Gary']
'''

# %%
def solution(data):
    if 3 <= len(data) <= 3: # 캐릭터의 수 제한
        for x in data: # 캐릭터
            for y in x[1:]: # 능력치
                if 10 <= y <= 100: # 능력치 제한
                    continue
                else: # 범위 밖 능력치 탐지
                    print(f'{x[0]}에게서 범위 밖 능력치를 탐지했습니다.') # 모든 캐릭터의 능력치를 봐야해서 return이 아닌 print

        mal_list = sorted([x[0] for x in data if sum(x[1:]) > 350]) # 능력치합 350 초과 -> 이름
        return mal_list

    else: # 캐릭터 수가 부족하거나 너무 많을 경우
        msg = '캐릭터 수가 부적절합니다. 3 ~ 10명의 캐릭터 정보를 입력해주세요'
        return msg

# %%
data = [['Gray', 98, 92, 85, 97], ['Gom', 98, 30, 21, 60], ['Allosa', 98, 90, 99, 98]]

solution(data)
# Out:
# ['Allosa', 'Gray']

# %% [markdown]
# # 문제2: 우편 번호 정렬
#
# https://100.pyalgo.co.kr/?page=12

# %%
'''
입출력 예
입력	출력
[['제주시 A동 한라산길 61', '제주시 B동 백록담길 63', '제주시 C동 사라봉길 31'], {'A동': 63007, 'B동': 63010, 'C동': 63002}]	['제주시 C동 사라봉길 31', '제주시 A동 한라산길 61', '제주시 B동 백록담길 63']
'''

# %%
data = [['제주시 A동 한라산길 61', '제주시 B동 백록담길 63', '제주시 C동 사라봉길 31'], {'A동': 63007, 'B동': 63010, 'C동': 63002}]

# 접근 1: 딕셔너리의 값을 기준으로 딕셔너리 재배열
# data[1] # 딕셔너리
# 1.1 리스트의 동과 딕셔너리의 키값이 동일함을 이용 => 딕셔너리의 키값을 index로 변경
l = {}
for idx, val in enumerate(data[1].values()):
    # print(idx, val)
    # 1.2 딕셔너리 생성
    l[idx] = val
# l # {0: 63007, 1: 63010, 2: 63002}
# 1.3 값을 기준으로 재배열
l2 = sorted(l.items(), key= lambda x : x[1])
# l2

# 2. data[0]의 index를 재배열된 idx로 바꿔 재배열
data2 = []
for i, _ in l2:
    # print(i) # i : 재배열된 index
    data2.append(data[0][i])
data2
# Out:
# ['제주시 C동 사라봉길 31', '제주시 A동 한라산길 61', '제주시 B동 백록담길 63']

# %%
data = [['제주시 A동 한라산길 61', '제주시 B동 백록담길 63', '제주시 C동 사라봉길 31'], {'A동': 63007, 'B동': 63010, 'C동': 63002}]
# 간소화
key2idx = {idx:val for idx, val in enumerate(data[1].values())}
# key2idx
rearranged = sorted(key2idx.items(), key= lambda x : x[1])
# rearranged
data2 = [data[0][i] for i, _ in rearranged]
# data2
# Out:
# ['제주시 C동 사라봉길 31', '제주시 A동 한라산길 61', '제주시 B동 백록담길 63']

# %%
# 함수화
def solution(data):
    key2idx = {idx:val for idx, val in enumerate(data[1].values())}
    rearranged = sorted(key2idx.items(), key= lambda x : x[1])
    res = [data[0][i] for i, _ in rearranged]
    return res

# %%
data = [['제주시 A동 한라산길 61', '제주시 B동 백록담길 63', '제주시 C동 사라봉길 31'], {'A동': 63007, 'B동': 63010, 'C동': 63002}]
solution(data)
# Out:
# ['제주시 C동 사라봉길 31', '제주시 A동 한라산길 61', '제주시 B동 백록담길 63']

# %% [markdown]
# # 문제3: 도서관 책 연도별 정렬
#
# https://100.pyalgo.co.kr/?page=13

# %%
'''
입력	출력
[['Moby Dick', 'To Kill a Mockingbird', '1984'], {'Moby Dick': 1851, 'To Kill a Mockingbird': 1960, '1984': 1949}]	['Moby Dick', '1984', 'To Kill a Mockingbird']
'''

# %%
data = [['Moby Dick', 'To Kill a Mockingbird', '1984'], {'Moby Dick': 1851, 'To Kill a Mockingbird': 1960, '1984': 1949}]

# %%
key2idx = {idx:val for idx, val in enumerate(data[1].values())}
key2idx
# Out:
# {0: 1851, 1: 1960, 2: 1949}

# %%
rearranged = sorted(key2idx.items(), key= lambda x : x[1])
rearranged
# Out:
# [(0, 1851), (2, 1949), (1, 1960)]

# %%
res = [data[0][i] for i, _ in rearranged]
res
# Out:
# ['Moby Dick', '1984', 'To Kill a Mockingbird']

# %%
def solution(data):
    if len(set(data[0])) == len(data[0]):
        key2idx = {idx:val for idx, val in enumerate(data[1].values())}
        rearranged = sorted(key2idx.items(), key= lambda x : x[1])
        return res

    else:
        return '데이터에 중복된 책이 있습니다. 데이터를 다시 입력해주세요'

# %%
data = [['Moby Dick', 'To Kill a Mockingbird', '1984'], {'Moby Dick': 1851, 'To Kill a Mockingbird': 1960, '1984': 1949}]
data2 = [['aaa', 'aaa', '1984'], {'aaa': 1851, 'aaa': 1960, '1984': 1949}]

# %%
solution(data)
# Out:
# ['Moby Dick', '1984', 'To Kill a Mockingbird']

# %%
solution(data2)
# Out:
# '데이터에 중복된 책이 있습니다. 데이터를 다시 입력해주세요'
